# %%
#!pip install --upgrade pixiedust
#!pip install --upgrade plotly
# Run this if you do not have these installed

# %%
import numpy as np
import pandas as pd
import plotly.offline as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.9</span>
#         </div>

# %%
df = pd.read_csv('combinedSet.csv')

# %%
df
# Out:
#              Lat         Lng             SubCategory  Distance to light
# 0      37.222112 -121.871588  ACC-Accident Complaint           0.013834
# 1      37.227864 -121.803752  ACC-Accident Complaint           0.026624
# 2      37.243317 -121.809268  ACC-Accident Complaint           0.021437
# 3      37.248466 -121.832579  ACC-Accident Complaint           0.000005
# 4      37.251459 -121.817494  ACC-Accident Complaint           0.013341
# 5      37.267304 -121.925399  ACC-Accident Complaint           0.006067
# 6      37.270714 -121.905793  ACC-Accident Complaint           0.021423
# 7      37.271190 -121.868530  ACC-Accident Complaint           0.044536
# 8      37.273379 -121.813269  ACC-Accident Complaint           0.015206
# 9      37.275900 -121.922547  ACC-Accident Complaint           0.115737
# 10     37.277067 -121.910076  ACC-Accident Complaint           0.090791
# 11     37.288615 -121.879533  ACC-Accident Complaint           0.046852
# ...

# %%
df.groupby('SubCategory')

# %%
df.groupby('SubCategory').mean()
# Out:
#                                  Lat         Lng  Distance to light
# SubCategory
# ACC-Accident Complaint     37.312345 -121.876377           0.051272
# ALL - Alleys               37.305651 -121.869660           0.046879
# APP - Appliances           37.309257 -121.865442           0.047409
# CON-Construction Material  37.316464 -121.861169           0.049824
# COU-Couch/Sofa             37.317605 -121.864605           0.044404
# FUR - Furniture            37.320272 -121.864715           0.045757
# GAR - Garbage              37.320146 -121.849661           0.045953
# GLA - Glass                37.313264 -121.872184           0.053444
# HAZ - Haz Mat              37.314185 -121.865774           0.044060
# LIT - Litter               37.320920 -121.851376           0.041171
# MAT-Mattresses             37.324297 -121.857879           0.041296
# OTH - Other                37.315634 -121.864907           0.051097
# REF-Refrigerators          37.303638 -121.825343           0.066288
# ...

# %%
df.groupby('SubCategory').count()
# Out:
#                             Lat   Lng  Distance to light
# SubCategory
# ACC-Accident Complaint       38    38                 38
# ALL - Alleys                  5     5                  5
# APP - Appliances            198   198                198
# CON-Construction Material   117   117                117
# COU-Couch/Sofa              835   835                835
# FUR - Furniture            8803  8803               8803
# GAR - Garbage              3561  3561               3561
# GLA - Glass                 478   478                478
# HAZ - Haz Mat               106   106                106
# LIT - Litter                 71    71                 71
# MAT-Mattresses             1282  1282               1282
# OTH - Other                2262  2262               2262
# REF-Refrigerators             8     8                  8
# TIR - Tires                 369   369                369
# TV                           41    41                 41
# ...

# %%
map_nam = {'ACC-Accident Complaint': 0, 'ALL - Alleys': 1, 'APP - Appliances': 2, 'CON-Construction Material': 3,
           'COU-Couch/Sofa': 4, 'FUR - Furniture': 5, 'GAR - Garbage': 6, 'GLA - Glass': 7, 'HAZ - Haz Mat': 8, 
           'LIT - Litter': 9, 'MAT-Mattresses': 10, 'OTH - Other': 11, 'REF-Refrigerators': 12, 'TIR - Tires': 13, 
           'TV': 14, 'YW - Yard Waste': 15}
df['SubCategory'] = df['SubCategory'].map(map_nam)
df1 = df1.assign()

# %%
display(df)
# Raw data on map
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             Dumping Sites
#         </div>
#     <div id="chartFigureaafa5c90" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <script>
#   window.iframeLoaded = window.iframeLoaded || function(iframe) {
#     try {
#       iframe.contentWindow.pdMessageListeners = [];
#       iframe.contentWindow["addPDMessageListener"] = function(listener){
#         iframe.contentWindow.pdMessageListeners.push(listener);
#       }
#       iframe.contentWindow.addEventListener("message", function(event){
#         iframe.contentWindow.pdMessageListeners.forEach(function(listener){
# ...
